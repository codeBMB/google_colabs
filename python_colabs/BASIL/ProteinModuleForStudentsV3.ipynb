# %% [markdown]
# <a href="https://colab.research.google.com/github/codeBMB/google_colabs/blob/BASIL/python_colabs/BASIL/ProteinModuleForStudentsV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![BASIL Logo](https://github.com/codeBMB/google_colabs/raw/85050639efc9fbbaf72a74c626fa4f5973bb49dc/python_colabs/BASIL/images/BASIL_logo.png)
#
# # **Determination of Protein Concentration Student Module**

# %% [markdown]
# # **Learning Goals**
# ---
# 1. Students will know how to perform and interpret a protein concentration assay.
# 2. Students will understand how they will use protein concentration in future experiments.
# 3. Students will gain analytical skills in sample preparation and data analysis.

# %% [markdown]
# # **Learning Objectives**
# ---
# 1. Students will identify factors that must be considered when choosing an appropriate assay for determination of protein concentration.
# 2. Students will prepare standard solutions of a known protein to create a standard curve.
# 3. Students will interpret absorbance measurements to determine the concentration of a protein solution.
# 4. Students will be able to convert protein concentration between mg/mL and M.
# 5. Students will explain the advantages of a linear standard curve *vs*. a nonlinear curve.
# 6. Students will adjust their unknown protein concentrations to make measurements within the effective range of the standard curve.

# %% [markdown]
# # **Introduction**
# ---
# Biochemical experiments require accurate determination of protein concentration, for example, for determining purification yields or to prepare a sample of appropriate concentration for analysis.  Protein quantitation usually relies on absorbance measurements. These measurements can be grouped into two broad categories: intrinsic absorbance and colorimetric/dye-binding (Table 1). **Intrinsic absorbance** measures absorbance of a protein without addition of any other reagents.  Most proteins absorb UV light with maximum absorbance at 280 nm due to absorbance of aromatic amino acid side chains (mainly tryptophan) and disulfide bonds; hence this assay is sensitive to the amino acid composition of the proteins (1, 2).  **Colorimetric and dye binding** assays are based on the change in absorbance of metal ions or organic dyes upon binding to proteins.  These methods are less sensitive to amino acid composition than intrinsic absorbance. When choosing an appropriate method, one must carefully consider potential interfering compounds.
#
# Factors to consider in choosing an assay include: sensitivity and working/linear range; interfering substances; effect on the protein (*e.g.* $A_280$ does not destroy protein, but other methods do); time and cost constraints; and availability of protein standard (solution of known concentration).  Table 1 compares several methods; additional information can be found in the original references or in the product information for commercially available reagents.

# %% [markdown]
# # **Beer-Lambert’s Law**
# ---
# When we use spectrophotometry to determine concentration, we relate the amount of light absorbed by the substance to its concentration using the Beer-Lambert law (also known as Beer’s law):
#
# $$A=εcl$$
#
# where $A$ is absorbance, $c$ is the concentration of the solution, $l$ is the pathlength (usually 1 cm), and $ε$ is the extinction coefficient. Absorptivity is a number specific to the wavelength at which absorbance is measured and the substance in solution that absorbs light. Extinction coefficient, also
#
# | Category | Method | Range | Based on | Interfering Agents |
# | ----- | :---: | :---: | :---: | ----- |
# | Intrinsic Absorbance | 280 nm \[1,2\] ε =  0 – 2 (mg/mL-cm)<sup>-1</sup> | 0.050-2.0 mg/mL | Absorbance of Tryptophan, Tyrosine, and disulfide bonds | Detergents Nucleic acids |
# | Colorimetric      ∙Chemical | Biuret \[3\] | 1.0-6.0 mg/ml | Cu<sup>+2</sup> reduced to Cu<sup>+1</sup> by peptide bond nitrogens | Ammonium salts |
# |  | Lowry \[4\] | 0.050-1.5 mg/ml | Biuret Cu<sup>+1</sup>-catalyzed reduction of Mb and W salts | Amino acid Nucleic acids Detergents Ammonium sulfate Lipids |
# |  | Bicinchoninic acid (BCA) \[5\] | 0.05-1.5 mg/ml | BCA binding to Cu<sup>+1</sup> in peptide bonds | Reducing sugars Copper chelating agents |
# | Colorimetric   ∙Dye    binding | Bradford \[6\] | 0.010-1.0 mg/ml | Coomassie Blue G-250 binding to proteins (preferentially to aromatic and Arg) | Detergents |
# |  | NanoOrange® fluorescence based \[7\] | 0.01-10.0 μg/ml | Binding to hydrophobic regions of proteins or detergent-coated proteins | Strong bases Reducing agents (DTT, 2-ME)  EDTA |
#
#
# **Table 1: Summary of methods for protein determination**
#
# known as absorptivity, is specific to the substance in solution that absorbs light, and the wavelength of the light absorbed.   Because absorbance, A, has no units, the units of **ε** must cancel those of ***c*** and ***l,*** and consequently, must be in inverse concentration and inverse length, M<sup>-1</sup>· cm<sup>-1</sup>.  The pathlength term *l* often drops out because standard UV-vis cuvettes have a 1 cm pathlength.  The concentration term *c* is normally in units of molarity, but occasionally a given extinction coefficient may have non-SI units such as micromolarity (μM), or mass concentration such as mg/ml.  Note two confusing pairs of terms: **absorptivity** should not to be confused with absorbance, and **pathlength** (measured in cm) should not be confused with wavelength (measured in nm).
#
# For a pure protein, one could simply determine the concentration using the Beer-Lambert Law and the extinction coefficient for the protein if known.  An estimated value can be calculated using the protein’s amino acid sequence (3); a useful online resource to perform this calculation can be found at [https://web.expasy.org/protparam/](https://web.expasy.org/protparam/).   If the sequence of a protein is not available, a very rough rule of thumb can be applied:  a 1 mg/ml solution of protein of typical amino acid composition in a 1 cm cuvette would be expected to have an absorbance of about 1\.  That is, most proteins have a mass-based extinction coefficient of around $1 (mg/ml)^{-1}cm^{-1}$; while inexact, this estimate can be helpful during the purification of a protein.
#
# While convenient, intrinsic absorbance measurement has the disadvantage that many other substances in a protein-containing sample also absorb light in the ultraviolet range.  In particular, nucleic acids (both RNA and DNA) absorb significant amounts of light at 280 nm, and are often present in a cell extract.  For this reason, it is often preferable to measure protein concentration using a colorimetric assay, where one first adds substance which reacts specifically with protein with a resulting color change, followed by measuring the absorbance change due to the reaction.  Such colorimetric assays react with proteins by mass, not mole, and in a way that is (at least approximately) independent of sequence, so that one does not need to know the molar mass or amino acid composition to measure concentration.  Although there are several well-characterized colorimetric assays available (Table 1), this experiment uses the dye-based Bradford assay due to its ease of use and reliability.

# %% [markdown]
# #**Bradford Assay**
# ---
# The Bradford Assay is a simple one-step method that can be performed as a standard assay (3.1 mL assay volume, requires 0.1 mL of protein, and a working range of approximately 0.1-1.0 mg/mL), in 96-well plates (same working range, but only 5 μL of protein is required) or as a micro assay (2 mL assay volume, requires 1 mL of dilute protein, 1-10 μg/mL working range).  The dye used in the Bradford assay is Coomassie Blue G-250, the same molecule commonly used for detecting the presence of proteins in polyacrylamide following electrophoresis.  In this assay, dye is mixed with the protein under acidic conditions.  The protein interacts with the dye *via* ionic and hydrophobic interactions of the polypeptide backbone and amino acid side chains.  (4)  The interaction stabilizes the anionic form of the dye, causing a color change from brownish-red to blue and a corresponding shift in the λ max from 465 nm (free dye) to 595 nm (dye-protein complex).  The reaction can occur in as little as 5 minutes.

# %% [markdown]
# #**Use of a standard curve**
# ---
# When you use spectrophotometric absorbance, whether intrinsic or colorimetric, to determine concentration, you are assuming a linear relationship between concentration and absorbance.  Linearity should always be confirmed by using a standard curve and graphical analysis, particularly when using dye-based concentration assays. A standard curve is generated by measuring the absorbance of a protein standard at a variety of known concentrations.  The data are plotted with concentration (independent variable) on the x-axis, and absorbance (dependent variable) on the y-axis.
#
# If the standard protein behaves similarly to the unknown protein(s), and both are handled in the assay the same way, the inferred concentration should be reasonably accurate, though it should be noted that dye-binding assays respond differently to different protein standards.  When designing an experiment, you should carefully consider the choice of standard protein and the choice of the assay.  The standard protein of choice is often bovine serum albumin (BSA).  It is small, soluble, well-behaved and relatively inexpensive. Other issues to consider when choosing an assay include: time required, sensitivity, difficulty, cost, and unfavorable interactions with components in the solution (detergents, reducing agents, etc.).

# %% [markdown]
# # **Protocol**
# ---
# **Purpose:** The purpose of this procedure is to measure unknown concentration of proteins in solution by mass (mg/mL), by preparing a absorbance *versus* concentration standard curve using bovine serum albumin. Absorbance is measured as visible absorption of dye/protein complexes in a colorimetric reaction.
#
# **Supplies needed**
#
# &emsp;<u>Equipment:</u>
#
#
# * Test tubes
# * Glass pipettes and pipettors
# * Micropipettors and tips
# * Plastic cuvette 3 mL (or 1mL)
# * Paraffin sealing film (Parafilm)
# * Spectrophotometer
# * 96 well plate
# * 96 well plate reader
# * Computer with internet access
#
# <u>Reagents</u>:
#
# * Bradford reagent (Sigma cat # B6916)
#
# * Standard BSA solution (Sigma cat # A2153), dissolved in water at 10 mg/ml; dilute to 1 mg/ml for working stock.
#
# * Unknown protein
#
# * Buffer (for dilutions and a blank; same as buffer used for unknown protein
#
# \
# **Safety:**  Bradford reagent contains phosphoric acid and methanol. Safety Data Sheet includes the following warnings: *It may be corrosive to metals. Causes severe skin burns and eye damage. Causes damage to organs.* Students and instructors should wear appropriate personal protective equipment: a lab coat, goggles, gloves, long pants and closed-toed shoes.

# %% [markdown]
# **Procedure** (Based on product information from Sigma-Aldrich (5). )
#
# <u>A.  Plan your experiment</u>
#
# 1. Prepare a table of standards and samples, either in a spreadsheet on your computer, or on paper in your lab notebook.  Cuvettes should include:
#    * One (two, for a double-beam instrument) **zero**, containing 3 mL of water, without dye or protein, for zeroing the instrument.
#    * One **blank**, which will contain only dye solution (no protein).
#    * One for each BSA standard.
#    * One for each unknown sample.
# 2. Assemble the required number of cuvettes in a sample holder and label them with permanent marker in an area which is not in the way of the light path.
#
# <u>A. Preparing BSA Standards</u>
#
# Using the buffer that your protein is stored in, prepare a series of 5-7 solutions of bovine serum albumin (BSA).  In a standard cuvette-based assay, standard solutions should range from 0.10 to 1.00 mg/mL.
#
# <u>B. Bradford Assay</u>
#
# Bradford Assay in 3.10 mL volume (*for 1.03 mL in parentheses*)
#
# 1. If Bradford reagent was obtained as a concentrated stock, dilute as instructed.
# 2. Add 3 mL (*1 mL*) of Bradford Reagent to each cuvette except for the “zero” cuvette(s), to which 3 mL (*1 mL*)  of water is added.  Add 100 μL (*30 μL*) of water to the blank, and 100 μL (*30 μL*)  of each BSA standard and unknowns to the rest.
# 3. Cover your cuvettes with small squares of parafilm and mix each one several times by gentle inversion.
# 4. Maintain at room temperature for 5-45 minutes.
# 5. Record absorbances at 595 nm of a spectrophotometer.
#
# Bradford 96-well Plate Assay (requires plate reader)
#
# 1. In each well add 5.00 μL of sample.
# 2. Add 250 μl of Bradford Reagent to each well.
# 3. Mix gently by shaking for 30 seconds.
# 4. Maintain at room temperature for 5-45 minutes.
# 5. Measure absorbance at 595 nm with the plate reader.
#
# **Clean-up:**
#
# Bradford reagent contains methanol and phosphoric acid.  While small amounts such as the contents of the cuvettes used may be disposed of down the sink, consult your chemical hygiene officer if disposal of larger amounts is required.  Empty cuvettes may be disposed of in regular trash after rinsing them to remove residual reagent.  Cuvettes should not be reused, as it is impossible to completely remove traces of reagent and protein from the plastic surface.

# %% [markdown]
# #**Interpreting Results**
# ---
# You will need the calculated concentration of protein in each standard, and measured absorbance for each sample.  An example analysis is shown in Table 2 (sample data) and Figure 1 (sample graph).
#
# 1. Calculate concentration (in mg/mL) of protein for each standard sample using the stock concentration of your standard and dilution volumes used to prepare each standard  sample.  Since the volume of Bradford reagent added is the same for all samples, “concentration” for purposes of this experiment will always refer to the concentration of protein in the volume of protein that you added it to your cuvette, not the concentration in the full cuvette volume including dye.  Set up a table of data as shown in Table 2
# 2. Use Excel to graph absorbance versus mg/mL protein for standard tubes (make sure to use scatter plot, not a line plot), as in Figure 1\.  Include the reading obtained for your dye-only blank.  Add a linear trendline, displaying the equation of the best-fit line for the graph (you will need to click “options”, then check the box next to “display equation”).
# 3. To determine the concentration of protein (mg/mL) in your unknown, use the equation of the line from the graph, substituting the unknown absorbance for Y and solving for X.  Be sure to use the correct units and number of significant figures. If you diluted your protein prior to performing the assay, calculate the concentration before the dilution using $C_1V_1= C_2V_2$ formula.
#
# <u>Relating standard curve data to concentration of your unknowns:</u>
#
# A standard curve can be used to estimate concentration of the unknowns you’ve measured.  For example, the arrows on the graph in Figure 1 identify the approximate point on the curve corresponding to an absorbance of 0.852, that of unknown 1, and by dropping from this point down to the x-axis, we can estimate the concentration of protein in that unknown to be somewhat greater than 0.4 mg/mL; perhaps 0.450 mg/mL.  We would be unable to estimate the concentration of protein in unknown 2, as its absorbance is greater than any of the standards.

# %% [markdown]
# | Tube \# | ID | Vol. of Standard (µl) | Vol. of Unknown (µl)  | Vol. Water (µl) | Vol. Dye (µl) | Initial Protein (mg/ml) | Abs. (595 nm) |
# | :---: | ----- | :---: | :---: | :---: | :---: | :---: | :---: |
# | 1 | Zero | 0 | 0 | 3100 | 0 |  0 | 0 |
# | 2 | Blank | 0 | 0 | 100 | 3000 | 0 | 0.449 |
# | 3 | Std1 | 100 | 0 | 0 | 3000 | 0.20 | 0.635 |
# | 4 | Std2 | 100 | 0 | 0 | 3000 | 0.40 | 0.805 |
# | 5 | Std3 | 100 | 0 | 0 | 3000 | 0.60 | 0.97 |
# | 6 | Std4 | 100 | 0 | 0 | 3000 | 0.80 | 1.09 |
# | 7 | Std5 | 100 | 0 | 0 | 3000 | 1.00 | 1.213 |
# | 13 | Unk1 | 0 | 100 | 0 | 3000 | \* | 0.852 |
# | 14 | Unk2 | 0 | 100 | 0 | 3000 | \* | 1.933 |
#
# **Table 2:  Sample table for setting up standards/unknowns and analyzing absorbance measurements. In this example, cuvette volume was 3 mL; these can be scaled down for 1 mL cuvettes or for multiwell plates.**

# %% [markdown]
# ![Protein Calibration Curve](https://github.com/codeBMB/google_colabs/raw/85050639efc9fbbaf72a74c626fa4f5973bb49dc/python_colabs/BASIL/images/Protein_calibration_curve.png)
#
# **Figure 1: Graph of blank and standards from Table 2 data**

# %% [markdown]
# For a more accurate determination, we can use the equation defined the best-fit line for the standard curve to calculate concentrations of our unknowns, if they fall within the linear portion of the graph. It is not unusual for a standard curve to become non-linear at higher concentration values, particularly where the absorbance becomes greater than 1\.  Before using a best-fit analysis, you must decide the range of concentration to include in your trendline fit.  In order to use the best-fit line equation to find the concentrations of your unknowns, you need to rearrange it from the $y = mx + b$ form by solving for x.  The equation in Figure 1 rearranges to give
# <div style="text-align: center;">
# $$x=\frac{y-0.4782}{0.7643}$$
# </div>
#
#
# The formula you obtain from the graph of your own data can be used to calculate your unknown concentrations.
#
# In the case of unknowns whose absorbance exceeds the linear portion of the curve (such as unknown 1 in the example), you should repeat the measurement using a diluted sample.  For example, you might decide to dilute an unknown by, first, combining 100 μL of sample with 400 μL of water.  This will produce a solution with one-fifth the concentration, which you can figure out using the $C_1V_1=C_2V_2$ equation; in this case $V_1 = 100 μL$ and $V_2 = 100 μL + 400 μL = 500 μL$.  You do not need to repeat the standard curve, as it remains valid, but you should take care to replicate the conditions you used previous, including incubation time between combining reagents and taking the absorbance readings.  Once the concentration of the diluted sample ($C_2$) is found, you can backtrack to find the concentration of the initial, more concentrated sample ($C_1$).
#
# If your protein is relatively pure, for example, after isolation by affinity chromatography, and you know its molar mass, you can convert the concentration you measured from mass/volume to molar.  For example, if you know your protein’s molar mass to be 43,000 and it has a concentration of 0.46 mg/mL, you can calculate its molar (or micromolar) concentration as follows:
#
# $$Protein Conc= \frac{0.46 mg}{mL}*\frac{1000 mL}{L}*\frac{1 g}{1000 mg}*\frac{1 mol protein}{43,000 g} = 11 μM$$

# %% [markdown]
# #  **Data Entry**
#
# In the following cell, your collected data can be entered in the x_data and y_data sections. Data should be entered separated by commas. You should only enter data for the x_data and y_data_raw lines.

# %%
# ENTER YOUR DATA HERE
# The only purpose of this cell is for your to insert the values for your calibration curve.

# x_data will be a list of the protein concentration
x_data = [0,0.2,0.4,0.6,0.8,1] # Initial Protein (mg/ml)

# y_data will be the list of the absorbance values at 595 nm for each of your samples.
# Check to ensure that the absorbance values in the y_data list correspond to the protein concentration values in the x_data list.
y_data_raw = [0.449,0.635,0.805,0.97,1.09,1.213] # Abs. (595 nm)

# %%
# Plotting your data

# These libraries are imported to create the plot (matplotlib.pyplot)
# to conduct of least square linear regression fit for your calibration curve (scipy.optimize.curve_fit)
# and to conduct standard data analysis (numpy).
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np

def linear_function(x, slope, intercept):
    return slope * x + intercept

# Perform baseline correction by subtracting the blank's absorbance
baseline_value = y_data_raw[0] # Assuming the first point is the blank
y_data = [y - baseline_value for y in y_data_raw]

params, covariance = curve_fit(linear_function, x_data, y_data)
slope, intercept = params

# Calculate standard errors
perr = np.sqrt(np.diag(covariance))
slope_error = perr[0]
intercept_error = perr[1]

# Prints the error values
print(f"Fitted Linear Equation: y = {slope:.4f}x + {intercept:.4f}")
print(f"Slope: {slope:.4f} +/- {slope_error:.4f}")
print(f"Intercept: {intercept:.4f} +/- {intercept_error:.4f}")

# This generates the plot for your raw data.
plt.scatter(x_data, y_data, label= 'Data')
plt.plot()

# This generates the linear least square fit line.
x_trendline = np.linspace(np.min(x_data), np.max(x_data), 100)
y_trendline = linear_function(x_trendline, slope, intercept)
plt.plot(x_trendline, y_trendline, color='red', linestyle='--', label=f'Trendline: y = {slope:.4f}x + {intercept:.4f}')

# This generates the labels.
plt.xlabel("Initial Protein (mg/ml)")
plt.ylabel("Abs. (595 nm)")
plt.title("Absorbance vs. Initial Protein Concentration")

# This generates the legend that includes the trendline.
plt.legend()
plt.show()
# Out:
# Fitted Linear Equation: y = 0.7643x + 0.0292
# Slope: 0.7643 +/- 0.0343
# Intercept: 0.0292 +/- 0.0207

# %% [markdown]
# # Challenge #1
# Use the next coding cell to change the plot to have a solid blue line instead of dashed red line, and red stars instead of blue circles.
#
# To do this, you will need to review the code in the previous "Plotting the Data" coding cell and see where you can make changes to make it work. If the answer is not obvious to you, you can also click on the "<u>generate</u> with AI" link in the coding cell and ask for help.

# %%
# @title
# SOLUTION

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np

def linear_function(x, slope, intercept):
    return slope * x + intercept

# Assuming x_data, y_data, slope, and intercept are already defined from previous cells

# This generates the plot for your raw data with star markers.
plt.scatter(x_data, y_data, label='Data', marker='*', color='red')
plt.plot()

# This generates the linear least square fit line.
x_trendline = np.linspace(np.min(x_data), np.max(x_data), 100)
y_trendline = linear_function(x_trendline, slope, intercept)
plt.plot(x_trendline, y_trendline, color='blue', linestyle='-', label=f'Trendline: y = {slope:.4f}x + {intercept:.4f}')

# This generates the labels.
plt.xlabel("Initial Protein (mg/ml)")
plt.ylabel("Abs. (595 nm)")
plt.title("Absorbance vs. Initial Protein Concentration")

# This generates the legend that includes the trendline.
plt.legend()
plt.show()

# %% [markdown]
# # Challenge #2
#
# If Challenge #1 seemed too simple, use the next coding cell to import the Seaborn library, using the command
#
# `import seaborn as sns`
#
# to start the coding cell and include the 95% confidence interval in the plot. Please note that since you already imported matplotlib.pyplot, scipy.optimize.curve_fit and numpy in the previous coding cell, you don't need to do that again.
#
# If the answer is not obvious to you, you can also click on the "generate with AI" link in the coding cell and ask for help.

# %%
# @title
import seaborn as sns

# Assuming x_data, y_data are already defined from previous cells

# Create the regression plot using seaborn
sns.regplot(x=x_data, y=y_data, marker='*', color='red', label='Data with 95% CI')

# Set labels and title
plt.xlabel("Initial Protein (mg/ml)")
plt.ylabel("Abs. (595 nm)")
plt.title("Absorbance vs. Initial Protein Concentration with 95% CI")

# Add legend and show plot
plt.legend()
plt.show()

# %% [markdown]
# # **References**
# ---
# 1\. 	Wetlaufer DB. 1963\. Ultraviolet spectra Of Proteins and Amino Acids, p. 303–390. *In* Anfinsen, CB, Bailey, K, Anson, ML, Edsall, JT (eds.), Advances in Protein Chemistry. Academic Press.
#
# 2\. 	Pace CN, Vajdos F, Fee L, Grimsley G, Gray T. 1995\. How to measure and predict the molar absorption coefficient of a protein. Protein Sci Publ Protein Soc 4:2411–2423.
#
# 3\. 	Gill SC, von Hippel PH. 1989\. Calculation of protein extinction coefficients from amino acid sequence data. Anal Biochem 182:319–326.
#
# 4\. 	Compton SJ, Jones CG. 1985\. Mechanism of dye response and interference in the Bradford protein assay. Anal Biochem 151:369–374.
#
# 5\. 	 Sigma Bradford Reagent Technical Bulletin (http://www.sigmaaldrich.com/content/dam/sigma-aldrich/docs/Sigma/Bulletin/b6916bul.pdf; Accessed July 15, 2016).
#
# *Module authors:*  Anya Goodman1, Colette Daubner3, Stefan M. Irby4, Julia R. Koeppe5, Ciara LaClair2, Jeffery L. Mills2, Suzanne O’Handley2, Michael Pikaart6, Rebecca Roberts7, and Paul A. Craig8  (1, California Polytechnic Institute; 2, Rochester Institute of Technology; 3, St. Mary’s University (TX); 4, Purdue University; 5, State University of New York – Oswego; 6, Hope College; 7, Ursinus College)
#
# *Python Notebook Authors:* Maddie Osborne, Jeffrey L. Mills, Paul A. Craig
#
# *This work was supported by the National Science Foundation through grants from NSF IUSE 1503811, 1503699, 1502720, 1503676, 1503710, 1503798, 1503734, 1709170, 1709805, 1709592, 1710583, 1709355, 1709278, 1710051, 2142033*

# %% [markdown]
# ![BASIL Logo](https://github.com/codeBMB/google_colabs/raw/85050639efc9fbbaf72a74c626fa4f5973bb49dc/python_colabs/BASIL/images/BASIL_logo.png)
